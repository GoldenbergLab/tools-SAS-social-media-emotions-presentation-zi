# %%
from fer import FER
import cv2
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
img = cv2.imread("raw-social-media-data/instagram-post.png")
detector = FER(mtcnn=True)
detector.detect_emotions(img)

faces = detector.detect_emotions(img)
print(faces)
# Out:
# [{'box': [179, 191, 34, 45], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.97, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.03}}]

# %%
image = draw_annotations(img, faces)
plt.imshow(image)

# %%
# Capture all the emotions on the image
captured_emotions = detector.detect_emotions(img)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(img)
# Out:
# [{'box': array([168, 186,  53,  53]), 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.97, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.02}}]

# %%
from fer import Video

video_filename = "raw-social-media-data/bobo.mp4"
video = Video(video_filename)

# Analyze video, displaying the output
detector = FER(mtcnn=True)
raw_data = video.analyze(detector, display=True)
df = video.to_pandas(raw_data)
# Out:
# INFO:fer:25.00 fps, 735 frames, 29.40 seconds
# INFO:fer:Making directories at output
# INFO:fer:Deleted pre-existing output\bobo_output.mp4
# 100%|████████████████████████████████████████████████████████████████████████████| 735/735 [05:45<00:00,  2.13frames/s]
# INFO:fer:Completed analysis: saved to output\bobo_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 6%
# INFO:fer:Compressing: 13%
# INFO:fer:Compressing: 20%
# INFO:fer:Compressing: 27%
# INFO:fer:Compressing: 34%
# INFO:fer:Compressing: 40%
# INFO:fer:Compressing: 47%
# INFO:fer:Compressing: 54%
# INFO:fer:Compressing: 61%
# INFO:fer:Compressing: 68%
# INFO:fer:Compressing: 74%
# INFO:fer:Compressing: 81%
# INFO:fer:Compressing: 88%
# INFO:fer:Compressing: 95%
# INFO:fer:Zip has finished

# %%
df.to_csv("bobo-emotions-by-frame.csv")

# %%
# Out:
# 0.25881147540983607

# %%
pltfig = df.plot(figsize=(20, 8), fontsize=16).get_figure()
